# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI client

# %%
os.getenv("OPENAI_API_KEY")

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages= [
        {"role":"system", "content":"You are a helpful assistant"},
        {"role":"user", "content":"Can you print 10 random word"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Here are 10 random words: amber, lighthouse, quiver, marigold, tundra, siphon, comet, velvet, ripple, zephyr

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=553, prompt_tokens=22, total_tokens=575, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=512, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages= [
        {"role":"system", "content":"You are a helpful assistant"},
        {"role":"user", "content":"Can you print 10 random word"}
    ],
    reasoning_effort="minimal"
)

print(response.choices[0].message.content)
# Out:
# Sure! Here are 10 random words:
#
# 1. lantern
# 2. ripple
# 3. mosaic
# 4. twilight
# 5. ember
# 6. velvet
# 7. compass
# 8. zephyr
# 9. quiver
# 10. lantern (appears again)
#
# If you want unique words, I can list 10 distinct ones.

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=79, prompt_tokens=22, total_tokens=101, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %% [markdown]
# #### Google genai Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    content=[
        "You are helpful assistant",
        "Can you print 15 random words?"
    ]
)

print(response.text)

# %% [markdown]
# ### Grok Client

# %%
from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY")
)

chat_completion = client.chat.completions.create(
    messages=[
        {"role":"system", "content":"You are a helpful assisstant"},
        {"role":"user", "content":"Can you print 20 random words?"}
    ],
    model="llama-3.3-70b-versatile"
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Space
# 2. Helicopter
# 3. Coffee
# 4. Dragon
# 5. Bicycle
# 6. Perfume
# 7. Llama
# 8. Guitar
# 9. Snowflake
# 10. Banana
# 11. Submarine
# 12. Pineapple
# 13. Football
# 14. Starfish
# 15. Computer
# 16. Harmonica
# 17. Butterfly
# 18. Parakeet
# 19. Motorcycle
# 20. Caramel
